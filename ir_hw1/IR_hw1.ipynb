# %%
import pymorphy2
import string
import collections
from nltk import tokenize
from pathlib import Path
import numpy as np

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
unlem_queries = [
    "Некоторые виды рыб размножаются не в воде, а на суше.",
    "Озеро Озеро — памятник природы.",
    "Канадский писатель стал первым лауреатом премии, названной в его честь."]

# %%
def get_doc_sentences(filename):
    with open(filename, "r", encoding="utf-8") as f:
        lines = f.readlines()
    sentences = []
    for line in lines:
        if line != "\n":
            sentences.extend(tokenize.sent_tokenize(line))
    return sentences

# %%
def get_lemmas(sentences):
    result = []
    empty_sentences_ids = []
    for i, sent in enumerate(sentences):
        sent = sent.translate(str.maketrans('', '', string.punctuation)).strip()
        splitted_sent = sent.split()
        lemmas = []
        for word in splitted_sent:
            p = morph.parse(word)[0]
            lemmas.append(p.normal_form)
        if lemmas:
            result.append(lemmas)
        else:
            empty_sentences_ids.append(i)
    return result, empty_sentences_ids

# %%
data_dir = Path.cwd() / "data"

docs = []
unlem_docs = []
for file in data_dir.iterdir():
    doc_sent = get_doc_sentences(data_dir / file)
    lemmas, empty_ids = get_lemmas(doc_sent)
    unlem_docs.extend([doc for i, doc in enumerate(doc_sent) if i not in empty_ids])
    docs.extend(lemmas)
    
queries, _ = get_lemmas(unlem_queries)

# %%
class Vectorizer:
    def __init__(self, docs, only_tf=False):
        self.docs = docs
        self.num_docs = len(docs)
        self.vocab = ["<unk>"] + list(set(word for doc in self.docs for word in doc))
        self.vocab_size = len(self.vocab)
        
        self.word2id = {word: idx for idx, word in enumerate(self.vocab)}
        self.only_tf = only_tf
        
    def compute_tf_idf(self):
        tf, df = np.zeros((self.num_docs, self.vocab_size), dtype=np.int), np.zeros(self.vocab_size, dtype=np.int)
        for i, doc in enumerate(self.docs):         
            v = np.zeros(self.vocab_size, dtype=np.int)
            uniq_words  = set(doc)
            for word in doc:
                v[self.word2id[word]] += 1
            
            for word in uniq_words:
                df[self.word2id[word]] += 1
            tf[i, :] = v
        df[0] = 1
        idf = np.log10(self.num_docs / df)
        # for <unk> word
        idf[0] = 0.0
        return tf, idf.reshape(1, -1)
    
    def fit_transform(self):
        self.tf, self.idf = self.compute_tf_idf()
        if self.only_tf:
            self.tf = 0.4*(self.tf != 0) + 0.6 * (self.tf / self.tf.max(axis=-1, keepdims=True))
            return self.tf * self.idf
        tf_idf_scores = self.tf * self.idf
        return tf_idf_scores
    
    def transform(self, docs):
        scores = np.zeros((len(docs), self.vocab_size), dtype=np.float) 
        for i, doc in enumerate(docs):
            for word in doc:
                word_idx = self.word2id.get(word, 0)
                if word_idx:
                    scores[i, word_idx] += 1
        if not self.only_tf:
            scores = scores * self.idf
        return scores
    
    def get_tf(self):
        return self.tf

# %%
vectorizer = Vectorizer(docs=docs)
docs_tfidf = vectorizer.fit_transform()
queries_tfidf = vectorizer.transform(queries)

# %%
docs_norm = np.linalg.norm(docs_tfidf, axis=1, keepdims=True)
queries_norm = np.linalg.norm(queries_tfidf, axis=1, keepdims=True)
dots = np.dot(docs_tfidf / docs_norm, (queries_tfidf / queries_norm).T)
dots.shape
# Out:
# (941, 3)

# %%
k = 15
top_ids = np.argpartition(dots, kth=range(-k,0), axis=0)[-k:, :][::-1, :]
col_mask = np.arange(len(queries)).reshape(1, -1).repeat(k, axis=0)
top_scores = dots[top_ids, col_mask]

# %%
for idx, q in enumerate(queries):
    print(f"#{idx + 1}: {unlem_queries[idx]}")
    top_docs, scores = top_ids[:, idx].tolist(), top_scores[:, idx].tolist()
    for d, s in zip(top_docs, scores):
        print(f"[{s:.3f}: {unlem_docs[d]}")
    print("\n\n")
# Out:
# #1: Некоторые виды рыб размножаются не в воде, а на суше.
# [0.394: Грунионы характеризуются необычным нерестовым поведением и являются одними из немногих видов рыб, которые откладывают икру не в воде, а на суше.
# [0.370: С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# [0.155: Виды хвостовых плавников рыб.
# [0.147: У некоторых видов они участвуют в терморегуляции (термогенезе).
# [0.144: У некоторых рыб могут отсутствовать брюшные, а в редких случаях — и грудные плавники.
# [0.128: Рыбы живут в воде, которая занимает огромные пространства.
# [0.127: Другими угрозами являются загрязнение воды, перегорождение рек, потепление, интродуцирование чужих видов, а также высыхание рек.
# [0.125: Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# [0.123: Весь процесс занимает 30 секунд, некоторые особи могут оставаться вне воды в течение нескольких минут.
# [0.122: Некоторые виды рыб (например, серебряный карась и разные виды сомов) имеют комплекс косточек (веберов аппарат), соединяющий ухо с плавательным пузырём.
# [0.121: Многие виды рыб изменяют тип питания на протяжении жизни: например, в молодом возрасте питаются планктоном, а позже — рыбами или крупными беспозвоночными.
# [0.121: Более половины всех живущих ныне видов позвоночных, а именно, согласно базе данных FishBase, около 31 тысячи видов, относятся к рыбам.
# [0.118: Химический тип воды гидрокарбонатно-хлоридно-кальциевый[2].
# [0.116: пелагические рыбы (нектон) — держатся в толще воды;
# [0.112: Число признанных видов продолжает меняться вследствие открытий новых видов, а также таксономических ревизий отдельных групп.
#
#
#
# #2: Озеро Озеро — памятник природы.
# [0.376: Природа
# [0.352: Озеро — озеро в России, располагается в 1,4 км северо-восточнее села Юматово на территории Верхнеуслонского района Республики Татарстан[1][3].
# [0.340: Озеро имеет округлую форму, длиной 40 м и шириной 35 м. Площадь водной поверхности озера составляет 0,08 га.
# [0.313: Памятник природы занимает акваторию одноименного озера, что на левобережной пойме Десны, с прибрежной полосой и водно-болотными угодьями (внутренняя часть изгиба котловины)[2].
# [0.259: 3	Природа
# [0.216: На озере имеются за́росли кубышки жёлтой, занесённой в Красную книгу Республики Татарстан[1].
# [0.199: Охраняется с 1978 года как гидрологический памятник природы регионального значения «Озеро Озеро»[2][1].
# [0.193: Статус памятника природы был присвоен решением Черниговского облисполкома от 27.04.1964 №236[1].
# [0.189: Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# [0.178: Памятник в Вальядолиде, Испания
# [0.159: «Озеро Магистратское» — гидрологический памятник природы местного значения, расположенный в южной части Деснянского района Черниговского горсовета (Черниговская область, Украина).
# [0.111: С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# [0.097: Будучи на протяжении многих лет активистом природоохранного движения[4] и страстным любителем наблюдения за птицами (помимо прочего, он возглавлял Центр наблюдения за птицами на острове Пели на озере Эри и входил в правление канадского отделения Всемирного фонда дикой природы[9]), он с начала 1990-х годов пытался опубликовать книгу, посвящённую птицам, но получил отказы в многочисленных издательствах[5].
# [0.094: Краткая переписка Тагора и Эйнштейна, «Записки о природе реальности», вошла в них как дополнение.
# [0.092: Памятник Тагору стоит в Москве в Парке Дружбы на пути к Северному речному порту у ст.
#
#
#
# #3: Канадский писатель стал первым лауреатом премии, названной в его честь.
# [0.547: Премия была названа в честь Грэма Гибсона, и он сам стал её первым лауреатом[4][11].
# [0.372: В честь Рабиндраната Тагора назван кратер на Меркурии[119].
# [0.340: Тагор стал первым её лауреатом из Азии.
# [0.277: 14 ноября 1913 года Тагор узнал, что стал лауреатом Нобелевской премии по литературе
# [0.263: Вскоре после издания «Одиннадцати канадских романистов», ставших самой известной из его книг[9], Гибсон стал одним из основателей Союза писателей Канады (англ.
# [0.263: В 1991 году Союз писателей Канады учредил премию за весомый вклад в улучшение условий жизни и творчества канадских писателей.
# [0.252: В 1973 году он издал сборник интервью с коллегами писателями «Одиннадцать канадских романистов», ставший манифестом современной канадской литературы[6].
# [0.247: Грэм Гибсон стал лауреатом Торонтской премии в области искусств в 1990 году и премии Уотерфронт Торонтского международного фестиваля авторов в 1993 году[4].
# [0.218: Он оказал влияние на нобелевского лауреата из Японии, писателя Ясунари Кавабату[108].
# [0.206: Он стал первым среди неевропейцев, кто был удостоен Нобелевской премии по литературе (1913)[10].
# [0.204: Кавалер ордена Канады (1992), лауреат премии Торонтского международного фестиваля авторов (1993), почётный член Королевского канадского географического общества (2007).
# [0.191: Writers’ Development Trust, позже Доверительный фонд писателей Канады), став его первым председателем.
# [0.179: Денежная премия Нобелевского комитета была пожертвована Тагором его школе в Шантиникетане, впоследствии ставшей первым университетом с бесплатным обучением[46][47].
# [0.176: В 1995 году по его инициативе канадский ПЕН-клуб совместно с Мэсси-колледжем Торонтского университета учредили программу поддержки писателей в изгнании, позднее ставшую международной.
# [0.173: Сооснователь и председатель Союза писателей Канады, основатель и председатель Доверительного фонда развития писателей, президент канадского отделения ПЕН-клуба.

# %%
vectorizer = Vectorizer(docs=docs, only_tf=True)
docs_tf = vectorizer.fit_transform()
queries_tf = vectorizer.transform(queries)

# %%
docs_norm = np.linalg.norm(docs_tf, axis=1, keepdims=True)
queries_norm = np.linalg.norm(queries_tf, axis=1, keepdims=True)
dots = np.dot(docs_tf / docs_norm, (queries_tf / queries_norm).T)

# %%
k = 15
top_ids = np.argpartition(dots, kth=range(-k,0), axis=0)[-k:, :][::-1, :]
col_mask = np.arange(len(queries)).reshape(1, -1).repeat(k, axis=0)
top_scores = dots[top_ids, col_mask]

# %%
for idx, q in enumerate(queries):
    print(f"#{idx + 1}: {unlem_queries[idx]}")
    top_docs, scores = top_ids[:, idx].tolist(), top_scores[:, idx].tolist()
    for d, s in zip(top_docs, scores):
        print(f"({s:.3f}): {unlem_docs[d]}")
    print("\n\n")
# Out:
# #1: Некоторые виды рыб размножаются не в воде, а на суше.
# (0.393): Грунионы характеризуются необычным нерестовым поведением и являются одними из немногих видов рыб, которые откладывают икру не в воде, а на суше.
# (0.327): С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# (0.230): Виды хвостовых плавников рыб.
# (0.207): У некоторых рыб могут отсутствовать брюшные, а в редких случаях — и грудные плавники.
# (0.192): У некоторых видов они участвуют в терморегуляции (термогенезе).
# (0.185): Многие виды рыб изменяют тип питания на протяжении жизни: например, в молодом возрасте питаются планктоном, а позже — рыбами или крупными беспозвоночными.
# (0.184): Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# (0.174): Рыбы живут в воде, которая занимает огромные пространства.
# (0.163): Гиногенез считается особой разновидностью партеногенеза, который в чистом виде у рыб не встречается.
# (0.158): Многие виды рыб содержатся в неволе — в аквариумах.
# (0.157): пелагические рыбы (нектон) — держатся в толще воды;
# (0.155): Другими угрозами являются загрязнение воды, перегорождение рек, потепление, интродуцирование чужих видов, а также высыхание рек.
# (0.152): Некоторые из таких рыб приспособлены к питанию планктоном, фильтруя его специализированными жаберными тычинками на жаберных дугах: так, разные виды толстолобиков (Hypophthalmichthys molitrix, Hypophthalmichthys nobilis) питаются исключительно за счёт этого ресурса и являются строго определёнными рыбами-фильтраторами микроскопических водорослей, которые живут в толще воды.
# (0.149): Содержание и разведение аквариумных рыб в некоторых случаях помогает сохранить редкие их виды, вымирающие в исконных местах обитания.
# (0.143): Весь процесс занимает 30 секунд, некоторые особи могут оставаться вне воды в течение нескольких минут.
#
#
#
# #2: Озеро Озеро — памятник природы.
# (0.378): Природа
# (0.297): Памятник природы занимает акваторию одноименного озера, что на левобережной пойме Десны, с прибрежной полосой и водно-болотными угодьями (внутренняя часть изгиба котловины)[2].
# (0.267): Озеро — озеро в России, располагается в 1,4 км северо-восточнее села Юматово на территории Верхнеуслонского района Республики Татарстан[1][3].
# (0.260): 3	Природа
# (0.243): Озеро имеет округлую форму, длиной 40 м и шириной 35 м. Площадь водной поверхности озера составляет 0,08 га.
# (0.199): На озере имеются за́росли кубышки жёлтой, занесённой в Красную книгу Республики Татарстан[1].
# (0.195): Охраняется с 1978 года как гидрологический памятник природы регионального значения «Озеро Озеро»[2][1].
# (0.189): Статус памятника природы был присвоен решением Черниговского облисполкома от 27.04.1964 №236[1].
# (0.182): «Озеро Магистратское» — гидрологический памятник природы местного значения, расположенный в южной части Деснянского района Черниговского горсовета (Черниговская область, Украина).
# (0.176): Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# (0.170): Памятник в Вальядолиде, Испания
# (0.111): С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# (0.111): — 496 с.
# (0.111): — 784 с.
# (0.100): Будучи на протяжении многих лет активистом природоохранного движения[4] и страстным любителем наблюдения за птицами (помимо прочего, он возглавлял Центр наблюдения за птицами на острове Пели на озере Эри и входил в правление канадского отделения Всемирного фонда дикой природы[9]), он с начала 1990-х годов пытался опубликовать книгу, посвящённую птицам, но получил отказы в многочисленных издательствах[5].
#
#
#
# #3: Канадский писатель стал первым лауреатом премии, названной в его честь.
# (0.514): Премия была названа в честь Грэма Гибсона, и он сам стал её первым лауреатом[4][11].
# (0.350): Тагор стал первым её лауреатом из Азии.
# (0.288): В честь Рабиндраната Тагора назван кратер на Меркурии[119].
# (0.280): Вскоре после издания «Одиннадцати канадских романистов», ставших самой известной из его книг[9], Гибсон стал одним из основателей Союза писателей Канады (англ.
# (0.260): 14 ноября 1913 года Тагор узнал, что стал лауреатом Нобелевской премии по литературе
# (0.253): В 1973 году он издал сборник интервью с коллегами писателями «Одиннадцать канадских романистов», ставший манифестом современной канадской литературы[6].
# (0.245): В 1991 году Союз писателей Канады учредил премию за весомый вклад в улучшение условий жизни и творчества канадских писателей.
# (0.243): Он стал первым среди неевропейцев, кто был удостоен Нобелевской премии по литературе (1913)[10].
# (0.233): Writers’ Development Trust, позже Доверительный фонд писателей Канады), став его первым председателем.
# (0.230): Грэм Гибсон стал лауреатом Торонтской премии в области искусств в 1990 году и премии Уотерфронт Торонтского международного фестиваля авторов в 1993 году[4].
# (0.222): Денежная премия Нобелевского комитета была пожертвована Тагором его школе в Шантиникетане, впоследствии ставшей первым университетом с бесплатным обучением[46][47].
# (0.221): Он оказал влияние на нобелевского лауреата из Японии, писателя Ясунари Кавабату[108].
# (0.205): В 1995 году по его инициативе канадский ПЕН-клуб совместно с Мэсси-колледжем Торонтского университета учредили программу поддержки писателей в изгнании, позднее ставшую международной.
# (0.185): Кавалер ордена Канады (1992), лауреат премии Торонтского международного фестиваля авторов (1993), почётный член Королевского канадского географического общества (2007).
# (0.174): Отличием первых рыб от бесчелюстных стала челюсть, производное одной из жаберных дуг.

# %% [markdown]
# # Language model

# %%
class LanguageModel:
    def __init__(self, tf):
        self.tf = tf
        
    def p(self, term):
        return np.sum(self.tf[:, term]) / np.sum(self.tf)
    
    def p_d(self, term, document):
        return self.tf[document, term] / np.sum(self.tf[document])
    
    def get_top_k(self, query_tf, param=0.5, k=15):
        r = []
        for i in range(len(self.tf)):
            pp = 1
            for j in range(len(query_tf)):
                if query_tf[j] != 0:
                    pp *= ((1 - param) * self.p(j) + param * self.p_d(j, i))
            r.append(pp)
        return np.argsort(np.array(r))[-k:][::-1]

# %%
vectorizer = Vectorizer(docs=docs, only_tf=True)
vectorizer.fit_transform()
queries_tf = vectorizer.transform(queries)
lm = LanguageModel(vectorizer.get_tf())
queries_tf = vectorizer.transform(queries)

# %%
def lm_result(query_tf, param=0.5):
    indices = lm.get_top_k(query_tf, param)
    for i, idx in enumerate(indices):
        print(f"{i+1}. {unlem_docs[idx]}")
    print("\n\n")

# %% [markdown]
# # Результат при lambda=0.5

# %%
for idx, q in enumerate(queries):
    print(f"#{idx + 1}: {unlem_queries[idx]}")
    lm_result(queries_tf[idx])
# Out:
# #1: Некоторые виды рыб размножаются не в воде, а на суше.
# 1. Грунионы характеризуются необычным нерестовым поведением и являются одними из немногих видов рыб, которые откладывают икру не в воде, а на суше.
# 2. С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# 3. Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# 4. Другими угрозами являются загрязнение воды, перегорождение рек, потепление, интродуцирование чужих видов, а также высыхание рек.
# 5. Некоторые из таких рыб приспособлены к питанию планктоном, фильтруя его специализированными жаберными тычинками на жаберных дугах: так, разные виды толстолобиков (Hypophthalmichthys molitrix, Hypophthalmichthys nobilis) питаются исключительно за счёт этого ресурса и являются строго определёнными рыбами-фильтраторами микроскопических водорослей, которые живут в толще воды.
# 6. Многие виды рыб изменяют тип питания на протяжении жизни: например, в молодом возрасте питаются планктоном, а позже — рыбами или крупными беспозвоночными.
# 7. У некоторых рыб могут отсутствовать брюшные, а в редких случаях — и грудные плавники.
# 8. У некоторых видов они участвуют в терморегуляции (термогенезе).
# 9. Гиногенез считается особой разновидностью партеногенеза, который в чистом виде у рыб не встречается.
# 10. Содержание и разведение аквариумных рыб в некоторых случаях помогает сохранить редкие их виды, вымирающие в исконных местах обитания.
# 11. На стадии личинки значительная часть газообмена осуществляется через кожу; несколько видов рыб имеют «лёгкие», где сохраняется увлажнённый воздух (амия); некоторые виды могут дышать воздухом непосредственно (гурами).
# 12. Икра может служить пищей для таких птиц, как кроншнепы и веретенники, а также для беспозвоночных (изоподы, Nereis, некоторые виды жуков и личинки мух)[2].
# 13. Эти импульсы позволяют составить довольно подробную картину окружающей среды: некоторые виды рыб, лишённые глаз, целиком ориентируются и перемещаются, полагаясь только на органы боковой линии.
# 14. Тем не менее, некоторые авторитетные исследователи в последние годы склонны снова объединять лучепёрых и лопастепёрых рыб в один класс Osteichthyes[10].
# 15. Весь процесс занимает 30 секунд, некоторые особи могут оставаться вне воды в течение нескольких минут.
#
#
#
# #2: Озеро Озеро — памятник природы.
# 1. Памятник природы занимает акваторию одноименного озера, что на левобережной пойме Десны, с прибрежной полосой и водно-болотными угодьями (внутренняя часть изгиба котловины)[2].
# 2. «Озеро Магистратское» — гидрологический памятник природы местного значения, расположенный в южной части Деснянского района Черниговского горсовета (Черниговская область, Украина).
# 3. Статус памятника природы был присвоен решением Черниговского облисполкома от 27.04.1964 №236[1].
# 4. Охраняется с 1978 года как гидрологический памятник природы регионального значения «Озеро Озеро»[2][1].
# 5. Природа
# 6. Озеро — озеро в России, располагается в 1,4 км северо-восточнее села Юматово на территории Верхнеуслонского района Республики Татарстан[1][3].
# 7. 3	Природа
# 8. Памятник в Вальядолиде, Испания
# 9. Озеро имеет округлую форму, длиной 40 м и шириной 35 м. Площадь водной поверхности озера составляет 0,08 га.
# 10. На озере имеются за́росли кубышки жёлтой, занесённой в Красную книгу Республики Татарстан[1].
# 11. Памятник Тагору стоит в Москве в Парке Дружбы на пути к Северному речному порту у ст.
# 12. Краткая переписка Тагора и Эйнштейна, «Записки о природе реальности», вошла в них как дополнение.
# 13. С помощью гиногенеза размножаются некоторые популяции или виды рыб, представленные в природе одними самками.
# 14. Не характерная для рыб забота о потомстве наблюдается преимущественно у видов в приливно-отливной зоне, в узких заливах и бухтах, а также в реках и озёрах.
# 15. В них он стремился к связи с божественным через обращение к природе и трогательное сопереживание человеческой драме.
#
#
#
# #3: Канадский писатель стал первым лауреатом премии, названной в его честь.
# 1. Премия была названа в честь Грэма Гибсона, и он сам стал её первым лауреатом[4][11].
# 2. Вскоре после издания «Одиннадцати канадских романистов», ставших самой известной из его книг[9], Гибсон стал одним из основателей Союза писателей Канады (англ.
# 3. В 1973 году он издал сборник интервью с коллегами писателями «Одиннадцать канадских романистов», ставший манифестом современной канадской литературы[6].
# 4. В честь Рабиндраната Тагора назван кратер на Меркурии[119].
# 5. В 1995 году по его инициативе канадский ПЕН-клуб совместно с Мэсси-колледжем Торонтского университета учредили программу поддержки писателей в изгнании, позднее ставшую международной.
# 6. В 1991 году Союз писателей Канады учредил премию за весомый вклад в улучшение условий жизни и творчества канадских писателей.
# 7. Тагор стал первым её лауреатом из Азии.
# 8. Грэм Гибсон стал лауреатом Торонтской премии в области искусств в 1990 году и премии Уотерфронт Торонтского международного фестиваля авторов в 1993 году[4].
# 9. Writers’ Development Trust, позже Доверительный фонд писателей Канады), став его первым председателем.
# 10. Он стал первым среди неевропейцев, кто был удостоен Нобелевской премии по литературе (1913)[10].
# 11. 14 ноября 1913 года Тагор узнал, что стал лауреатом Нобелевской премии по литературе
# 12. Денежная премия Нобелевского комитета была пожертвована Тагором его школе в Шантиникетане, впоследствии ставшей первым университетом с бесплатным обучением[46][47].
# 13. Кавалер ордена Канады (1992), лауреат премии Торонтского международного фестиваля авторов (1993), почётный член Королевского канадского географического общества (2007).
# 14. Он оказал влияние на нобелевского лауреата из Японии, писателя Ясунари Кавабату[108].
# 15. Согласно ему, Тагор имел возможность стать масоном в молодости, предположительно пройдя посвящение в одной из лож, во время своего нахождения в Англии[50].[значимость?]

# %% [markdown]
# # Результат при lambda=0.9

# %%
for idx, q in enumerate(queries):
    print(f"#{idx + 1}: {unlem_queries[idx]}")
    lm_result(queries_tf[idx], param=0.9)
# Out:
# #1: Некоторые виды рыб размножаются не в воде, а на суше.
